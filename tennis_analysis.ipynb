# %% [markdown]
# <a href="https://colab.research.google.com/github/mann718/Best-README-Template/blob/master/tennis_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("7")
# Out:
# 7

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir("/content/drive/MyDrive/tennis_analysis")

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1RfUD3bzr3I7X7ov4Gr9k5Wls_0jm2x4T/tennis_analysis

# %%
# !pip install -r requirements.txt

# %%
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...

# %%
# !python probe_models.py --video /content/drive/MyDrive/tennis_analysis/inputs/input_video.mp4 --frame 50
# Out:
# Device: cuda
# Frame: 1920x1080
# ...
#
#   Loading PekingU/rtdetr_v2_r18vd...
# ...
# You are using a model of type rt_detr_v2 to instantiate a model of type rt_detr. This is not supported for all configurations of models and can yield errors.
# Loading weights: 100% 526/526 [00:00<00:00, 744.31it/s, Materializing param=model.encoder_input_proj.2.1.weight]
# RTDetrForObjectDetection LOAD REPORT from: PekingU/rtdetr_v2_r18vd
# Key                                                        | Status     |  |
# -----------------------------------------------------------+------------+--+-
# model.decoder.layers.{0, 1, 2}.encoder_attn.n_points_scale | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#   ✓ GOOD  classes=80  has_person=True  max_score=0.9111
#   top3: [('0.9111', 'person'), ('0.9014', 'person'), ('0.8808', 'person')]
#
#   Loading PekingU/rtdetr_v2_r50vd...
# ...

# %%
# !python quick_test_7.py --video /content/drive/MyDrive/tennis_analysis/inputs/input_video.mp4 --frame 50
# Out:
# Frame: 1920x1080
# Device: cuda   Model: PekingU/rtdetr_v2_r50vd
# Loading with RTDetrForObjectDetection (V1 class — works with both v1 and v2 checkpoints)...
# ...
# You are using a model of type rt_detr_v2 to instantiate a model of type rt_detr. This is not supported for all configurations of models and can yield errors.
# Loading weights: 100% 764/764 [00:01<00:00, 690.61it/s, Materializing param=model.encoder_input_proj.2.1.weight]
# RTDetrForObjectDetection LOAD REPORT from: PekingU/rtdetr_v2_r50vd
# Key                                                                 | Status     |  |
# --------------------------------------------------------------------+------------+--+-
# model.decoder.layers.{0, 1, 2, 3, 4, 5}.encoder_attn.n_points_scale | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#
# Raw:  min=0.0000  max=1.0000  mean=0.4867
# Norm: min=-2.1179  max=2.6400  mean=0.1710
#
# ...

# %%
# !python tennis_analyzer.py \
    --input /content/tennis_analysis/input/input_video.mp4 \
    --output output/analyzed.mp4 \
    --rtdetr PekingU/rtdetr_v2_r50vd \
    --vitpose usyd-community/vitpose-base-simple \
    --skip 1
# Out:
# [RTDetr] Loading PekingU/rtdetr_v2_r50vd on cuda...
# preprocessor_config.json: 100% 444/444 [00:00<00:00, 2.81MB/s]
# The image processor of type `RTDetrImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# ...
# config.json: 5.28kB [00:00, 15.4MB/s]
# model.safetensors: 100% 172M/172M [00:01<00:00, 91.0MB/s]
# Loading weights: 100% 770/770 [00:01<00:00, 735.56it/s, Materializing param=model.encoder_input_proj.2.1.weight]
# The tied weights mapping and config for this model specifies to tie class_embed.0.bias to model.decoder.class_embed.1.bias, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# ...

# %%
# !python tennis_analyzer9.py --input /content/drive/MyDrive/tennis_analysis/inputs/sample_1080.mp4 --output output/out_1080.mp4
# Out:
# [RF-DETR] Loading RFDETRLarge at res=960...
# [2026-03-31 11:59:32] [INFO] rf-detr - File rf-detr-large-2026.pth already exists with correct MD5 hash.
# [2026-03-31 11:59:32] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-03-31 11:59:32] [WARNING] rf-detr - Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-03-31 11:59:33] [INFO] rf-detr - File rf-detr-large-2026.pth already exists with correct MD5 hash.
# [RF-DETR] Ready.
# [Pose] Loading usyd-community/vitpose-base-simple...
# ...
# Loading weights: 100% 199/199 [00:00<00:00, 5108.74it/s]
# [Pose] Ready.
#
# [Pipeline] 1920×1080 @ 50.0fps  total=549
# ...

# %%
from rfdetr.assets.coco_classes import COCO_CLASSES
id2label = {(k): v for k, v in COCO_CLASSES.items()}

# %%
id2label
# Out:
# {1: 'person',
#  2: 'bicycle',
#  3: 'car',
#  4: 'motorcycle',
#  5: 'airplane',
#  6: 'bus',
#  7: 'train',
#  8: 'truck',
#  9: 'boat',
#  10: 'traffic light',
#  11: 'fire hydrant',
#  13: 'stop sign',
#  14: 'parking meter',
#  15: 'bench',
#  16: 'bird',
#  17: 'cat',
#  18: 'dog',
#  19: 'horse',
#  20: 'sheep',
#  21: 'cow',
#  22: 'elephant',
#  23: 'bear',
#  24: 'zebra',
#  25: 'giraffe',
#  27: 'backpack',
#  28: 'umbrella',
#  31: 'handbag',
#  32: 'tie',
#  33: 'suitcase',
#  34: 'frisbee',
#  35: 'skis',
#  36: 'snowboard',
#  37: 'sports ball',
#  38: 'kite',
#  39: 'baseball bat',
#  40: 'baseball glove',
#  41: 'skateboard',
#  42: 'surfboard',
#  43: 'tennis racket',
#  44: 'bottle',
#  46: 'wine glass',
#  47: 'cup',
#  48: 'fork',
#  49: 'knife',
#  50: 'spoon',
#  51: 'bowl',
#  52: 'banana',
#  53: 'apple',
#  54: 'sandwich',
#  55: 'orange',
#  56: 'broccoli',
#  57: 'carrot',
#  58: 'hot dog',
#  59: 'pizza',
#  60: 'donut',
#  61: 'cake',
#  62: 'chair',
# ...

# %%
# Tune exclusion zones visually first:
# !python tennis_analyzer10.py --input /content/drive/MyDrive/tennis_analysis/inputs/sample_1080.mp4 --show-zones --no-pose --max 100
# Out:
# [RF-DETR] Loading RFDETRLarge at res=960...
# [2026-03-31 13:15:58] [INFO] rf-detr - File rf-detr-large-2026.pth already exists with correct MD5 hash.
# [2026-03-31 13:15:58] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-03-31 13:15:58] [WARNING] rf-detr - Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-03-31 13:16:00] [INFO] rf-detr - File rf-detr-large-2026.pth already exists with correct MD5 hash.
# [RF-DETR] Ready.
#
# [Pipeline] 1920×1080 @ 50.0fps  total=549
# [2026-03-31 13:16:01] [WARNING] rf-detr - Model is not optimized for inference. Latency may be higher than expected. You can optimize the model for inference by calling model.optimize_for_inference().
# ...

# %%
# !python tennis_analyzer10.py --input /content/drive/MyDrive/tennis_analysis/inputs/sample_1080.mp4 --output output/out_1080.mp4 \
  --top-frac 0.20 --left-frac 0.08 --right-frac 0.08 \
  --rfdetr-res 960
# Out:
# [RF-DETR] Loading RFDETRLarge at res=960...
# [2026-03-31 13:17:08] [INFO] rf-detr - File rf-detr-large-2026.pth already exists with correct MD5 hash.
# [2026-03-31 13:17:08] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-03-31 13:17:08] [WARNING] rf-detr - Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-03-31 13:17:09] [INFO] rf-detr - File rf-detr-large-2026.pth already exists with correct MD5 hash.
# [RF-DETR] Ready.
# [Pose] Loading usyd-community/vitpose-base-simple...
# Loading weights: 100% 199/199 [00:00<00:00, 641.55it/s]
# [Pose] Ready.
#
# [Pipeline] 1920×1080 @ 50.0fps  total=549
# ...

# %%
# Tune exclusion zones visually first:
# !python tennis_analyzer13.py --input /content/drive/MyDrive/tennis_analysis/inputs/input_video.mp4 --top-frac 0.12 --left-frac 0.16 --right-frac 0.17 --show-zones --no-pose --max 100
# Out:
# [RF-DETR] Loading RFDETRLarge at res=960...
# [2026-04-01 12:43:06] [INFO] rf-detr - File rf-detr-large-2026.pth already exists with correct MD5 hash.
# [2026-04-01 12:43:06] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-04-01 12:43:06] [WARNING] rf-detr - Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-04-01 12:43:07] [INFO] rf-detr - File rf-detr-large-2026.pth already exists with correct MD5 hash.
# [RF-DETR] Ready.
# [Court] Calibration file not found: court_calib.json
# [Court] No court_calib.json. Run: python tennis_analyzer.py --calibrate --input video.mp4
#
# [Pipeline] 1920×1080 @ 30.0fps  total=214
# ...

# %%
# !python tennis_analyzer13.py --input /content/drive/MyDrive/tennis_analysis/inputs/input_video.mp4 --output output/out_sample.mp4 \
  --top-frac 0.12 --left-frac 0.16 --right-frac 0.17 \
  --rfdetr-res 960
# Out:
# [RF-DETR] Loading RFDETRLarge at res=960...
# [2026-04-01 14:00:07] [INFO] rf-detr - File rf-detr-large-2026.pth already exists with correct MD5 hash.
# [2026-04-01 14:00:07] [WARNING] rf-detr - Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-04-01 14:00:07] [WARNING] rf-detr - Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# [2026-04-01 14:00:08] [INFO] rf-detr - File rf-detr-large-2026.pth already exists with correct MD5 hash.
# [RF-DETR] Ready.
# [Pose] Loading usyd-community/vitpose-base-simple...
# ...
# Loading weights: 100% 199/199 [00:00<00:00, 23233.58it/s]
# [Pose] Ready.
# [Court] Calibration loaded from court_calib.json
# [Court] Calibration loaded — court lines enabled
#
# [Pipeline] 1920×1080 @ 30.0fps  total=214
# ...

# %%
# !python tennis_analyzer13.py --calibrate --input /content/drive/MyDrive/tennis_analysis/inputs/input_video.mp4
# Out:
# [Court] Homography computed. Reprojection check:
#   corner 1: expected [577 302], got [577 302], err=0.00px
#   corner 2: expected [1334  302], got [1334  302], err=0.00px
#   corner 3: expected [364 857], got [364 857], err=0.00px
#   corner 4: expected [1565  857], got [1565  857], err=0.00px
# [Court] Calibration saved → court_calib.json
#
# ✅ Calibration saved using hardcoded points!
